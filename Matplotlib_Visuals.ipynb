# %%
import sklearn
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pandas.tools.plotting import scatter_matrix

# %%
# %run  Data.ipynb

# %%
DF_1 = final[["Country", "ATMs per 1000 Adults"]].sort_values("ATMs per 1000 Adults", ascending=0)
DF_1.head()
# Out:
#       Country  ATMs per 1000 Adults
# 8      Canada            221.126457
# 42   Portugal            176.810262
# 2   Australia            160.137780
# 27      Japan            127.454390
# 15    Germany            123.056697

# %%
DF_1.plot(kind="barh", x="Country", color="navy")
fig = plt.figure(figsize=(18,100))
plt.show(fig)

# %%
scatter_matrix(final[["ATMs per 1000 Adults", "iPhone Users", "Starbucks Locations", "GEI Score"]])
plt.show()
