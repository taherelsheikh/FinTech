# %%
from bokeh.charts import Bar, Scatter, Histogram, output_notebook, show, defaults
from bokeh.plotting import figure, output_notebook, show
# %run  Data.ipynb

# %%
final.head()
# Out:
#                 Country Code  ATMs per 1000 Adults  iPhone Users  \
# 0  United Arab Emirates   AE             61.909397      17943000
# 1             Argentina   AR             58.841633      60664000
# 2             Australia   AU            160.137780      31770000
# 3               Austria   AT            119.094724      13471000
# 4            Azerbaijan   AZ             35.082586      10697000
#
#    Starbucks Locations  GEI Score
# 0                  144       58.8
# 1                  108       22.2
# 2                   22       72.5
# 3                   18       63.5
# 4                    4       31.1

# %%
from bokeh.io import output_notebook, show
from bokeh.layouts import gridplot
from bokeh.plotting import figure

output_notebook()


x = final["GEI Score"]
y0 = final["ATMs per 1000 Adults"]
y1 = final['iPhone Users']
y2 = final["Starbucks Locations"]

s1 = figure(width=300, plot_height=300, title="ATMs per 1000 Adults")
s1.circle(x, y0, size=10, color="navy", alpha=0.5)

s2 = figure(width=300, height=300, title='iPhone Users')
s2.triangle(x, y1, size=10, color="firebrick", alpha=0.5)


s3 = figure(width=300, height=300, title='Starbucks Locations')
s3.square(x, y2, size=10, color="orange", alpha=0.5)

p = gridplot([[s1, s2, s3]],toolbar_location=None)

show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="28f4a1b1-638c-4be8-b565-d09bddd1790a">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="4ffe776c-646b-4b3b-a8ba-e0a55d7798d6"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
# ...

# %% [markdown]
# <img src="Bokeh/bokeh_1.png">

# %%
df_1 = final[["Country", "GEI Score"]].sort_values("GEI Score", ascending=1)
from bokeh.charts.attributes import CatAttr


defaults.plot_width = 900
defaults.plot_height = 400

bar_plot_2 = Bar(df_1,values='GEI Score', label=CatAttr(columns=['Country'],sort=False),title="GEI Score", color="green", legend=None, toolbar_location=None)
bar_plot_2.title.text_font_size = '10pt'
#plt = Bar(data, values='values', label=CatAttr(columns=['labels'], sort=False),)
output_notebook()
show(bar_plot_2)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="8a4b04c1-953e-4370-8159-4176cabb79a6">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="51df1d35-f9e6-4429-8679-c086927d2ac6"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
# ...

# %% [markdown]
# <img src="Bokeh/bokeh_2.png">

# %% [markdown]
# ![](file:///Users/Taher/Desktop/Bokeh_Visuals.html)

# %%
df_2 = final[["Country", "Starbucks Locations"]].sort_values("Starbucks Locations", ascending=1)
from bokeh.charts.attributes import CatAttr


defaults.plot_width = 900
defaults.plot_height = 400

bar_plot_2 = Bar(df_2,values='Starbucks Locations', label=CatAttr(columns=['Country'],sort=False),title="Starbucks Locations", color="red", legend=None, toolbar_location=None)
bar_plot_2.title.text_font_size = '10pt'
#plt = Bar(data, values='values', label=CatAttr(columns=['labels'], sort=False),)
output_notebook()
show(bar_plot_2)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="10b630aa-acdf-4244-9d62-81ab26e42ec7">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="639675cf-ea90-4efd-9ed9-d50ce249c1a6"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
# ...

# %% [markdown]
# <img src="Bokeh/bokeh_3.png">

# %%
df_3 = final[["Country", "ATMs per 1000 Adults"]].sort_values("ATMs per 1000 Adults", ascending=1)
from bokeh.charts.attributes import CatAttr


defaults.plot_width = 900
defaults.plot_height = 400

bar_plot_3 = Bar(df_3,values='ATMs per 1000 Adults', label=CatAttr(columns=['Country'],sort=False),title="ATMs per 1000 Adults", color="wheat", legend=None, toolbar_location=None)
bar_plot_3.title.text_font_size = '10pt'
#plt = Bar(data, values='values', label=CatAttr(columns=['labels'], sort=False),)
output_notebook()
show(bar_plot_3)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="19706519-2ca9-4df5-9548-a2965bddca43">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="1921c413-559a-4eb0-8b40-eb8f7fd81b17"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
# ...

# %% [markdown]
# <img src="Bokeh/bokeh_4.png">
